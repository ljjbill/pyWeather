# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#set up list for each column in dataframe
City_name=[]
Cloudiness=[]
Country=[]
Date=[]
Humidity=[]
Lng=[]
Lat=[]
Max_Temp = []
Wind_speed=[]


# Loop through the list of cities and perform a request for data on each
for city in cities:
    #set base URL
    url = "http://api.openweathermap.org/data/2.5/weather?"
    #set temp unit
    units = "metric"
    # Build query URL and request your results in Celsius
    query_url = f"{url}appid={api_key}&q={city}&units={units}"
    weather_json = requests.get(query_url).json()
    try:
        City_name.append(weather_json["name"])
        Cloudiness.append(weather_json["clouds"]["all"])
        Country.append(weather_json["sys"]["country"])
        Date.append(weather_json["dt"])
        Humidity.append(weather_json["main"]["humidity"])
        Lng.append(weather_json["coord"]["lon"])
        Lat.append(weather_json["coord"]["lat"])
        Max_Temp.append(weather_json["main"]["temp_max"])
        Wind_speed.append(weather_json["wind"]["speed"])
        print(f"{city} is found")
    except:
        print("Oops, this city is not found")
# Out:
# bredasdorp is found
# rikitea is found
# atuona is found
# saint-philippe is found
# bathsheba is found
# kiunga is found
# vestmannaeyjar is found
# busselton is found
# hengshui is found
# qaanaaq is found
# vaini is found
# avarua is found
# iralaya is found
# port elizabeth is found
# tiksi is found
# lebu is found
# cape town is found
# punta arenas is found
# baghdad is found
# mahebourg is found
# tuktoyaktuk is found
# ushuaia is found
# balsas is found
# Oops, this city is not found
# mataura is found
# verkh-usugli is found
# cabedelo is found
# albany is found
# paamiut is found
# betafo is found
# chokurdakh is found
# klaksvik is found
# guerrero negro is found
# prince albert is found
# stokmarknes is found
# longyan is found
# kaitangata is found
# port alfred is found
# Oops, this city is not found
# ribeira grande is found
# sao joao da barra is found
# abay is found
# hobart is found
# mar del plata is found
# wattegama is found
# ngorongoro is found
# Oops, this city is not found
# jacareacanga is found
# san cristobal is found
# carnarvon is found
# isangel is found
# east london is found
# hambantota is found
# mehamn is found
# krasnyy kut is found
# batesville is found
# Oops, this city is not found
# fort nelson is found
# sars is found
# norman wells is found
# fairbanks is found
# Oops, this city is not found
# banjar is found
# kisumu is found
# hithadhoo is found
# pochutla is found
# mount gambier is found
# talnakh is found
# saskylakh is found
# jamestown is found
# araouane is found
# te anau is found
# tasiilaq is found
# lemoore is found
# barrow is found
# ulaanbaatar is found
# petropavlovsk-kamchatskiy is found
# hilo is found
# srednekolymsk is found
# cabra is found
# bethel is found
# bluff is found
# hasaki is found
# Oops, this city is not found
# sioux lookout is found
# swift current is found
# muisne is found
# kununurra is found
# leeton is found
# Oops, this city is not found
# mitsamiouli is found
# douentza is found
# saldanha is found
# hue is found
# Oops, this city is not found
# bibiani is found
# narsaq is found
# kapaa is found
# Oops, this city is not found
# nizhniy odes is found
# victoria is found
# hermanus is found
# adrar is found
# meulaboh is found
# nouakchott is found
# arraial do cabo is found
# castro is found
# longyearbyen is found
# carauari is found
# Oops, this city is not found
# saint george is found
# makakilo city is found
# luderitz is found
# Oops, this city is not found
# Oops, this city is not found
# niles is found
# rochegda is found
# kloulklubed is found
# Oops, this city is not found
# sitka is found
# basco is found
# dikson is found
# airai is found
# mogadishu is found
# marsa matruh is found
# Oops, this city is not found
# vilyuysk is found
# faanui is found
# awjilah is found
# nara is found
# sao filipe is found
# kavieng is found
# samarai is found
# waddan is found
# georgetown is found
# broome is found
# puerto ayora is found
# Oops, this city is not found
# susanville is found
# baruun-urt is found
# huayang is found
# vardo is found
# changchun is found
# new norfolk is found
# davidson is found
# antalaha is found
# sao jose da coroa grande is found
# kargasok is found
# oltu is found
# hofn is found
# arvin is found
# malaya serdoba is found
# lompoc is found
# Oops, this city is not found
# portobelo is found
# marzuq is found
# chapais is found
# udankudi is found
# merauke is found
# rincon is found
# mildura is found
# Oops, this city is not found
# rawson is found
# enshi is found
# sinnamary is found
# ontario is found
# sungurlu is found
# cabo san lucas is found
# kumba is found
# Oops, this city is not found
# mandalgovi is found
# Oops, this city is not found
# mardin is found
# Oops, this city is not found
# ngunguru is found
# Oops, this city is not found
# chuy is found
# barranca is found
# yeniseysk is found
# kachiry is found
# kavaratti is found
# buala is found
# maumere is found
# ambilobe is found
# soe is found
# nabire is found
# port hedland is found
# karratha is found
# severo-kurilsk is found
# otjiwarongo is found
# mayo is found
# khatanga is found
# thompson is found
# ekhabi is found
# ancud is found
# yamethin is found
# esperance is found
# nurota is found
# nuuk is found
# corbelia is found
# ixtapa is found
# pithoragarh is found
# gainesville is found
# provideniya is found
# lisakovsk is found
# puerto baquerizo moreno is found
# villa corzo is found
# grindavik is found
# Oops, this city is not found
# plettenberg bay is found
# duku is found
# coahuayana is found
# yenagoa is found
# arica is found
# la paz is found
# yellowknife is found
# bam is found
# tautira is found
# tenenkou is found
# Oops, this city is not found
# hobyo is found
# noumea is found
# Oops, this city is not found
# namibe is found
# ketchikan is found
# takoradi is found
# koshurnikovo is found
# iqaluit is found
# plyussa is found
# torbay is found
# jasper is found
# Oops, this city is not found
# Oops, this city is not found
# nadvoitsy is found
# tura is found
# arman is found
# fare is found
# Oops, this city is not found
# ust-maya is found
# katsuura is found
# bubaque is found
# swan hill is found
# salalah is found
# Oops, this city is not found
# mendoza is found
# cervo is found
# Oops, this city is not found
# cherskiy is found
# belyy yar is found
# butaritari is found
# shebunino is found
# adre is found
# tuatapere is found
# kyabram is found
# upernavik is found
# goalpara is found
# kamenka is found
# kisaran is found
# glendive is found
# souillac is found
# mata is found
# mazkeret batya is found
# saint-georges is found
# muros is found
# yuanping is found
# presidencia roque saenz pena is found
# porkhov is found
# husavik is found
# lakes entrance is found
# punuare is found
# celestun is found
# port hardy is found
# sola is found
# bilma is found
# namatanai is found
# vagur is found
# medeiros neto is found
# constantine is found
# los llanos de aridane is found
# ashtian is found
# saint anthony is found
# turukhansk is found
# jumla is found
# Oops, this city is not found
# acapulco is found
# Oops, this city is not found
# tornio is found
# ishigaki is found
# Oops, this city is not found
# mokhotlong is found
# samana is found
# male is found
# gubkinskiy is found
# moberly is found
# kodiak is found
# ust-kulom is found
# opunake is found
# salamiyah is found
# sosua is found
# springbok is found
# atar is found
# Oops, this city is not found
# arkhangelsk is found
# alofi is found
# avera is found
# Oops, this city is not found
# palana is found
# ponta delgada is found
# Oops, this city is not found
# paramirim is found
# oum hadjer is found
# gizo is found
# terme is found
# codrington is found
# buraydah is found
# jiazi is found
# imatra is found
# big spring is found
# ponta do sol is found
# berlevag is found
# Oops, this city is not found
# Oops, this city is not found
# thunder bay is found
# padang is found
# naze is found
# biak is found
# sabang is found
# leshukonskoye is found
# pangnirtung is found
# alghero is found
# cockburn town is found
# Oops, this city is not found
# constitucion is found
# portland is found
# kudahuvadhoo is found
# palmer is found
# colorado springs is found
# dingle is found
# cidreira is found
# Oops, this city is not found
# tual is found
# lagoa is found
# Oops, this city is not found
# teya is found
# leningradskiy is found
# prince george is found
# joshimath is found
# aksu is found
# Oops, this city is not found
# kruisfontein is found
# Oops, this city is not found
# Oops, this city is not found
# muhos is found
# ostrovnoy is found
# palauig is found
# aden is found
# isabela is found
# Oops, this city is not found
# plouzane is found
# bima is found
# santiago is found
# oshakati is found
# rio grande is found
# yeppoon is found
# ossora is found
# fortuna is found
# labuhan is found
# yerbogachen is found
# aklavik is found
# santa cruz is found
# rossland is found
# geraldton is found
# camalu is found
# homer is found
# cermik is found
# pueblo nuevo is found
# talavera is found
# kodinsk is found
# nikolskoye is found
# oussouye is found
# caravelas is found
# Oops, this city is not found
# Oops, this city is not found
# Oops, this city is not found
# clyde river is found
# altamira is found
# oslomej is found
# kichera is found
# abu samrah is found
# bend is found
# Oops, this city is not found
# akcakoca is found
# seddon is found
# lokoja is found
# port lincoln is found
# manokwari is found
# komsomolskiy is found
# ngawen is found
# Oops, this city is not found
# mareeba is found
# genhe is found
# Oops, this city is not found
# mascote is found
# ayagoz is found
# grand gaube is found
# marawi is found
# Oops, this city is not found
# vwawa is found
# aykhal is found
# vanimo is found
# trincomalee is found
# luanda is found
# filingue is found
# northam is found
# neuquen is found
# paltinis is found
# houma is found
# vattalkundu is found
# alekseyevsk is found
# eyl is found
# raymond is found
# tikrit is found
# luzino is found
# pidhorodna is found
# marsh harbour is found
# diu is found
# tessalit is found
# bilibino is found
# kalmunai is found
# manggar is found
# sayla is found
# coquimbo is found
# gallup is found
# tiruvallur is found
# ilulissat is found
# gat is found
# tiznit is found
# comodoro rivadavia is found
# andreapol is found
# kortkeros is found
# lavrentiya is found
# tahoua is found
# garmsar is found
# port blair is found
# san andres is found
# beloha is found
# hami is found
# yatou is found
# Oops, this city is not found
# tagusao is found
# quartucciu is found
# filadelfia is found
# kyshtovka is found
# porto novo is found
# gambiran is found
# vagamo is found
# noshiro is found
# taywarah is found
# llangefni is found
# bystryy istok is found
# tiarei is found
# ust-kuyga is found
# cayenne is found
# superior is found
# chiredzi is found
# camocim is found
# tromso is found
# cukai is found
# batemans bay is found
# gunjur is found
# peci is found
# rock sound is found
# beausejour is found
# ljungby is found
# cascavel is found
# lakheri is found
# lingao is found
# weihai is found
# mocuba is found
# srivardhan is found
# panalingaan is found
# curuguaty is found
# decatur is found
# notodden is found
# mitu is found
# moshi is found
# purranque is found
# puerto quijarro is found
# Oops, this city is not found
# evensk is found
# campo grande is found
# torbat-e jam is found
# bull savanna is found
# jadu is found
# fukue is found
# khani is found
# springdale is found
# ushtobe is found
# saint-pierre is found
# deputatskiy is found
# mazamari is found
# lorengau is found
# ashoknagar is found
# conde is found
# slavyanka is found
# lieto is found
# morondava is found
# forio is found
# xichang is found
# shangqiu is found
# myanaung is found
# Oops, this city is not found
# charters towers is found
# garowe is found
# broken hill is found
# great yarmouth is found
# atasu is found
# gambo is found
# Oops, this city is not found
# madera is found
# mana is found
# west wendover is found
# san patricio is found
# los andes is found
# weligama is found
# santa maria is found
# camacha is found
# pacific grove is found
# bozoum is found
# jalu is found
# college is found
# banepa is found
# flin flon is found
# stephenville is found
# ampanihy is found
# limbe is found
# mantua is found
# lodja is found
# slave lake is found
# terrace is found
# itoman is found
# magadan is found
# tazovskiy is found
# oktyabrskiy is found
# ucluelet is found
# lata is found
# paraopeba is found
# shawnee is found
# north bend is found
# beyneu is found
# zhezkazgan is found
# ouadda is found
# ongandjera is found
# sorland is found
# chunskiy is found
# kopychyntsi is found
# inuvik is found
# eugene is found
# zheleznodorozhnyy is found
# russell is found
# kansanshi is found
# zhangjiakou is found
# Oops, this city is not found
# pervomayskoye is found
# kalush is found
# sri aman is found
# benjamin aceval is found
# corn island is found
# lazaro cardenas is found
# cubara is found
# vaitape is found
# pisco is found
# shakhtinsk is found
# Oops, this city is not found
# romanovka is found
# richards bay is found
# glenluce is found
# Oops, this city is not found
# nouadhibou is found
# carutapera is found
# Oops, this city is not found
# nuyo is found
# zhigansk is found
# xai-xai is found
# bay roberts is found
# dzilam gonzalez is found
# valentin gomez farias is found
# ulaangom is found
# Oops, this city is not found
# kahului is found
# kupang is found
# andra is found
# Oops, this city is not found
# tshikapa is found
# chicama is found
# atikokan is found
# sompeta is found
# Oops, this city is not found
# otane is found
# Oops, this city is not found
# bambous virieux is found
# champasak is found
# ustek is found
# shelburne is found
# denpasar is found
# westport is found
# port said is found
# maningrida is found
# astoria is found
# zaraza is found
# bahia blanca is found
# haines junction is found
# kilkenny is found
# sambava is found
# obihiro is found
# maposeni is found
# izhma is found
# Oops, this city is not found
# sidhi is found
# bolobo is found

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City_name": City_name,
    "Cloudiness": Cloudiness,
    "Country": Country,
    "Date": Date,
    "Humidity": Humidity,
    "Lng": Lng,
    "Lat": Lat,
    "Max_Temp": Max_Temp,
    "Wind_speed": Wind_speed 
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#         City_name  Cloudiness Country        Date  Humidity     Lng    Lat  \
# 0      Bredasdorp         100      ZA  1544151600        88   20.04 -34.53
# 1         Rikitea          56      PF  1544153801        97 -134.97 -23.12
# 2          Atuona          68      PF  1544153801       100 -139.03  -9.80
# 3  Saint-Philippe          90      CA  1544151600        92  -73.48  45.36
# 4       Bathsheba          20      BB  1544151600        74  -59.52  13.22
#
#    Max_Temp  Wind_speed
# 0     17.00        1.00
# 1     26.51        5.17
# 2     27.26        8.72
# 3      0.10        5.70
# 4     26.00        7.70

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
y=weather_data['Max_Temp']
#Plot chart
plt.scatter(weather_data['Lat'], y, s = 30, color = 'blue', edgecolor = 'black', alpha = .75)
# Add reference lines
for i in list(np.arange(-45, 45, 10)):
    plt.axhline(i,linewidth=1, color='grey')
for i in list(np.arange(-60, 81, 20)):    
    plt.axvline(i,linewidth=1, color='grey')
#Titles
plt.suptitle('City Latitude vs Max Temperature (12/6/2018)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
# Out:
# Text(0, 0.5, 'Max Temperature (C)')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
y=weather_data['Humidity']
#Plot chart
plt.scatter(weather_data['Lat'], y, s = 30, color = 'blue', edgecolor = 'black', alpha = .75)
# Add reference lines
for i in list(np.arange(0, 100, 10)):
    plt.axhline(i,linewidth=1, color='grey')
for i in list(np.arange(-60, 81, 20)):    
    plt.axvline(i,linewidth=1, color='grey')
#Titles
plt.suptitle('City Latitude vs Humidity (12/6/2018)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
# Out:
# Text(0, 0.5, 'Humidity (%)')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
y=weather_data['Cloudiness']
#Plot chart
plt.scatter(weather_data['Lat'], y, s = 30, color = 'blue', edgecolor = 'black', alpha = .75)
# Add reference lines
for i in list(np.arange(0, 100, 10)):
    plt.axhline(i,linewidth=1, color='grey')
for i in list(np.arange(-60, 81, 20)):    
    plt.axvline(i,linewidth=1, color='grey')
#Titles
plt.suptitle('City Latitude vs Cloudiness (12/6/2018)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
# Out:
# Text(0, 0.5, 'Cloudiness (%)')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
y=weather_data['Wind_speed']
#Plot chart
plt.scatter(weather_data['Lat'], y, s = 30, color = 'blue', edgecolor = 'black', alpha = .75)
# Add reference lines
for i in list(np.arange(0, 30, 5)):
    plt.axhline(i,linewidth=1, color='grey')
for i in list(np.arange(-60, 81, 20)):    
    plt.axvline(i,linewidth=1, color='grey')
#Titles
plt.suptitle('City Latitude vs Wind Speed (12/6/2018)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
# Out:
# Text(0, 0.5, 'Wind Speed (mph)')
